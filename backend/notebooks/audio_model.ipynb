# %%
import assemblyai as aai

# %%
transcriber=aai.Transcriber()
transcript=transcriber.transcribe()
transcript
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 transcriber=aai.Transcriber()
#       2 transcript=transcriber.transcribe(r"C:\Users\varda\Downloads\luvvoice.com-20250818-MMjlhB.mp3")
#       3 transcript
#
# File c:\Users\varda\AppData\Local\Programs\Python\Python311\Lib\site-packages\assemblyai\transcriber.py:989, in Transcriber.__init__(self, client, config, max_workers)
#     958 def __init__(
#     959     self,
#     960     *,
#    (...)    963     max_workers: Optional[int] = None,
#     964 ) -> None:
#     965     """
#     966     Initializes the `Transcriber` with the given parameters.
#     967
#    (...)    987         ```
#     988     """
# --> 989     self._client = client or _client.Client.get_default()
#     991     self._impl = _TranscriberImpl(
#     992         client=self._client,
# ...

# %%
transcript.text
# Out:
# 'A casa airplane hit by cargo truck at mumbai airport.'
